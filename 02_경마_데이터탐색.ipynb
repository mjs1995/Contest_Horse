# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import missingno as msno
# %matplotlib inline

# %%
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["font.size"] = 15

# %%
df = pd.read_csv("서울경마_3년_2_날짜.csv",encoding='ms949')

# %%
df.head()
# Out:
#    id  순위  마번      마명 산지 성별  연령    중량  기수명 조교사명  ...      4코너     G-3F  \
# 0   1   1   8     일마레  한  수   3  55.5   먼로  서범석  ...  00:48.3  00:37.6
# 1   2   2   6    천하여제  한  암   3  53.0  문세영  지용철  ...  00:48.2  00:38.1
# 2   3   3   4    백두거포  한  거   3  55.0  마누엘  구자흥  ...  00:49.0  00:38.0
# 3   4   4  12  쏘아라흑장군  한  수   3  55.0  이준철  김대근  ...  00:49.5  00:38.0
# 4   5   5  11   퍼스트선더  한  수   4  55.0  김정준  심승태  ...  00:49.5  00:38.0
#
#       G-1F     경주기록              날짜  날씨 주로상태  주로습도  등급    거리
# 0  00:13.2  01:19.8  2019년04월27일(토)  맑음   포화  0.17  국5  1300
# 1  00:13.5  01:20.2  2019년04월27일(토)  맑음   포화  0.17  국6  1300
# 2  00:13.3  01:20.8  2019년04월27일(토)  맑음   포화  0.17  국6  1300
# 3  00:13.4  01:21.2  2019년04월27일(토)  맑음   포화  0.17  국6  1300
# 4  00:13.3  01:21.2  2019년04월27일(토)  맑음   포화  0.17  국6  1300
#
# [5 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28121 entries, 0 to 28120
# Data columns (total 30 columns):
# id       28121 non-null int64
# 순위       28121 non-null int64
# 마번       28121 non-null int64
# 마명       28121 non-null object
# 산지       28121 non-null object
# 성별       28121 non-null object
# 연령       28121 non-null int64
# 중량       28121 non-null float64
# 기수명      28121 non-null object
# 조교사명     28121 non-null object
# 마주명      28119 non-null object
# 마체중      28121 non-null int64
# 단승       28121 non-null float64
# 연승       28121 non-null float64
# 장구현황     22465 non-null object
# 구간별순위    28121 non-null object
# S-1F     28121 non-null object
# 1코너      28121 non-null object
# 2코너      28121 non-null object
# 3코너      28121 non-null object
# 4코너      28121 non-null object
# G-3F     28121 non-null object
# G-1F     28121 non-null object
# 경주기록     28121 non-null object
# 날짜       28121 non-null object
# 날씨       28121 non-null object
# ...

# %%
msno.matrix(df)

# %%
df.isnull().sum()
# Out:
# id          0
# 순위          0
# 마번          0
# 마명          0
# 산지          0
# 성별          0
# 연령          0
# 중량          0
# 기수명         0
# 조교사명        0
# 마주명         2
# 마체중         0
# 단승          0
# 연승          0
# 장구현황     5656
# 구간별순위       0
# S-1F        0
# 1코너         0
# 2코너         0
# 3코너         0
# 4코너         0
# G-3F        0
# G-1F        0
# 경주기록        0
# 날짜          0
# 날씨          0
# 주로상태        0
# 주로습도     1293
# 등급          0
# 거리          0
# dtype: int64

# %%
df['산지'].value_counts()
# Out:
# 한     21572
# 미      5763
# 호       589
# 일       113
# 뉴        37
# 캐        31
# 아일       14
# 영         1
# 프         1
# Name: 산지, dtype: int64

# %%
sns.set(style='darkgrid')
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='산지', palette=sns.color_palette("Blues_r"),
              order = df['산지'].value_counts().index)

# %%
df['성별'].value_counts()
# Out:
# 암    10932
# 수    10266
# 거     6923
# Name: 성별, dtype: int64

# %%
sns.set(style='darkgrid')
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='성별', palette=sns.color_palette("Blues_r"),
              order = df['성별'].value_counts().index)

# %%
df['연령'].value_counts()
# Out:
# 3    11415
# 4     7886
# 5     4193
# 2     2556
# 6     1434
# 7      498
# 8      118
# 9       21
# Name: 연령, dtype: int64

# %%
sns.set(style='darkgrid')
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='연령',  palette=sns.color_palette("Blues_r"),
             order = df['연령'].value_counts().index)

# %%
df['중량'].value_counts()
# Out:
# 52.0    5019
# 54.0    3548
# 55.0    3438
# 53.0    2970
# 51.0    2461
# 56.0    2353
# 53.5    1670
# 52.5    1585
# 54.5    1489
# 55.5    1118
# 57.0     856
# 56.5     775
# 51.5     584
# 58.0      83
# 50.0      63
# 57.5      61
# 59.0      20
# 50.5      12
# 58.5       9
# 60.0       4
# 59.5       3
# Name: 중량, dtype: int64

# %%
sns.set(style='darkgrid')
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='중량', palette=sns.color_palette("Blues_r"),
              order = df['중량'].value_counts().index)

# %%
df['마체중'].value_counts()
# Out:
# 483    465
# 468    458
# 472    455
# 477    449
# 481    448
# 470    447
# 479    442
# 475    441
# 478    431
# 466    420
# 474    417
# 471    417
# 480    415
# 482    414
# 464    410
# 467    409
# 473    406
# 465    405
# 476    404
# 488    391
# 485    391
# 486    387
# 484    387
# 487    382
# 469    380
# 490    380
# 463    379
# 489    378
# 462    368
# 492    364
#       ...
# 549      4
# 562      4
# 397      4
# 564      3
# 566      3
# 571      2
# 598      2
# 380      2
# 391      2
# 567      2
# 561      2
# 390      2
# 613      2
# 565      1
# 383      1
# 573      1
# 388      1
# 610      1
# 580      1
# 556      1
# 389      1
# 597      1
# 611      1
# 379      1
# 386      1
# 617      1
# 601      1
# 569      1
# 568      1
# 579      1
# Name: 마체중, Length: 198, dtype: int64

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,6))
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.tick_params(axis='x', labelsize=0) 
sns.countplot(data=df, x='마체중',  palette=sns.color_palette("Blues"))

# %%
df['등급'].value_counts()
# Out:
# 국5     6583
# 국4     5767
# 국6     3243
# 국3     3222
# 외4     2062
# 외3     1876
# 국2     1580
# 외1     1304
# 외2     1297
# 국1     1177
# 외미검      10
# Name: 등급, dtype: int64

# %%
sns.set(style='darkgrid')
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='등급', palette=sns.color_palette("Blues_r"),
              order = df['등급'].value_counts().index)

# %%
df['거리'].value_counts()
# Out:
# 1300    7841
# 1000    6634
# 1200    5149
# 1700    4201
# 1400    2127
# 1800    1481
# 2000     368
# 1900     263
# 2300      57
# Name: 거리, dtype: int64

# %%
sns.set(style='darkgrid')
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='거리', palette=sns.color_palette("Blues_r"),
              order = df['거리'].value_counts().index)

# %%
df['순위'] = df['순위'].astype(object)
df['마번'] = df['마번'].astype(object)

# %%
df_p=df.pivot_table(index="순위",columns="연령",aggfunc='size')
df_p=df_p.fillna(0)
plt.figure(figsize=(20,10))
sns.heatmap(df_p,cmap="Blues",annot=True,fmt='.0f')
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["font.size"] = 15

# %%
df['순위'] = df['순위'].astype(object)
df['마번'] = df['마번'].astype(object)
df_p=df.pivot_table(index="순위",columns="마번",aggfunc='size')
df_p=df_p.fillna(0)
plt.figure(figsize=(20,10))
sns.heatmap(df_p,cmap="Blues",annot=True,fmt='.0f')
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["font.size"] = 15

# %%
df_p=df.pivot_table(index="순위",columns="중량",aggfunc='size')
df_p=df_p.fillna(0)
plt.figure(figsize=(20,10))
sns.heatmap(df_p,cmap="Blues",annot=True,fmt='.0f')
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["font.size"] = 15

# %%
df_p=df.pivot_table(index="순위",columns="마체중",aggfunc='size')
df_p=df_p.fillna(0)
plt.figure(figsize=(20,10))
plt.rcParams["font.family"] = 'Malgun Gothic'
sns.heatmap(df_p,cmap="Blues")

# %%
df_p=df.pivot_table(index="순위",columns="산지",aggfunc='size')
df_p=df_p.fillna(0)
plt.figure(figsize=(20,10))
sns.heatmap(df_p,cmap="Blues",annot=True,fmt='.0f')
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["font.size"] = 15

# %%
df_p=df.pivot_table(index="순위",columns="성별",aggfunc='size')
df_p=df_p.fillna(0)
plt.figure(figsize=(20,10))
sns.heatmap(df_p,cmap="Blues",annot=True,fmt='.0f')

# %%
df_p=df.pivot_table(index="순위",columns="등급",aggfunc='size')
df_p=df_p.fillna(0)
plt.figure(figsize=(20,10))
sns.heatmap(df_p,cmap="Blues",annot=True,fmt='.0f')

# %%
df_p=df.pivot_table(index="순위",columns="거리",aggfunc='size')
df_p=df_p.fillna(0)
plt.figure(figsize=(20,10))
sns.heatmap(df_p,cmap="Blues",annot=True,fmt='.0f')
